# %%
sox_10_terms = {}
for dataset in ['ReMap_ChIP-seq.gmt']:
    with open(f'data/{dataset}') as f:
        data = f.readlines()
    for l in data:
        split_data = l.replace('\n', '').split('\t')
        tf = split_data[0].split('_')[0]
        if tf == 'SOX10':
            sox_10_terms[f"{split_data[0]} {dataset}"] = split_data[2:]
len(sox_10_terms)
union_set = set()
for k in sox_10_terms.keys():
    if len(union_set) == 0:
        union_set = set(sox_10_terms[k])
    else:
        union_set = union_set.union(set(sox_10_terms[k]))
len(union_set)
# Out:
# 1450

# %%
cluster_1_up =  "RXRA, FOSL2, CEBPD, ZNF217, ZNF385A, KLF4, ELF1, ZBTB49, ATF3, ZHX2, TAL1, ZNF317, BACH1, TBX19, NR1H3, CEBPA, STAT3, MYCL, FOXO1, RBPJ, RUNX1, AHR, NFATC3, CEBPB, ETS2, GATA1, USF1, MBD2, MXI1, ETV3, NKX23, STAT5A, RUNX2, NFE2L2, VENTX, NFATC1, MAFB, BHLHE40, HIVEP3, PPARD, ETS1, ZNF200, E2F5, NEUROG2, BCL6, ELK3, KLF1, EOMES, ARID3A, MYB, RFX5, VDR, TBXT, LEF1, HBP1, NR3C1, MBD4, SPI1, STAT6, ASCL2, FOS, CREM, RARA, MAX, PRDM13, HIVEP1, GTF2IRD1, GFI1B, ARNTL, KLF13, TCF7, NR4A1, FLI1, ETV3L, NR4A2, JUNB, ZNF552, BACH2, IRF1, STAT1, KLF2, PAX5, ETV6, IKZF1, NCOA3, MEF2B, ZNF589, KLF6, ZNF277, TLX1, AHRR, ZFP57, ZNF852, PRDM1, NFE2, ZBTB3, ZNF701, ZBTB7B, NFYC, JAZF1, STAT2, JDP2, PBX4, NFKB2, TFEB, SATB1, STAT5B, ZNF490, LYL1, MYBL1, ZNF799, ZNF350, IRF4, ZNF746, ZBTB24, GMEB1, NFIL3, ZNF705A, EGR3, ZBTB34, POU2F2, TIGD3, ZNF641, RUNX3, NANOGP8, HHEX, BATF, NR4A3, ZNF331, NFKB1, EGR2, FOXP3, ZNF600, ZNF586, MSC, ZNF319, GCM1, FOSB, ZBTB2, ZNF341, LTF, ZFAT, ZNF75D, TRERF1, HMX3, ARID3B, RELB, ZNF792, IRF9, MIXL1, ATF6, CREBL2, TBX21, ZNF564, SNAI3, ZNF429, ZKSCAN4, IRF2, ZNF438, STAT4, IRF8, HMX2, BATF3, ZNF671, BHLHE23, ZNF467, MTERF4, ZNF396, HLX, PHF21A, NFATC2, ZNF683, ZBTB32, SPIB, ZNF222, SPIC, CREB5, RLF, ZNF831, MTF1, POU2AF1, TRAFD1, ZNF354A, FOXN2, ZSCAN32, ZNF101, MXD1, NFE2L3, ZNF80, ZNF267, ZNF230, BORCS8MEF2B, ETV7, REL, IKZF2, GFI1, PLSCR1, BATF2, IRF7, ELF4, RAG1, CEBPE, ZNF394, NFE4, TFEC, ZNF763, ZBED2, TET2, ZNF443, E2F2, LIN54, SP100, CSRNP1, SCML4, AKNA, IRF5, IKZF3, SP110, SP140, SP140L, ARID5A"
cluster_1_up = set(cluster_1_up.split(", "))

cluster_2_up = "MYPOP, ZNF446, ZFP41, KMT2B, ELK1, ZNF865, NFIC, SCX, FBXL19, PRR12, DEAF1, ZNF142, FIZ1, SETDB1, ZNF324, HSF4, ZNF784, HSF1, ZNF768, ZNF316, GMEB2, ZNF74, AHDC1, ZNF592, MEF2D, ZNF710, ZBTB7A, E4F1, ZBTB47, MLXIP, ZNF174, ZBTB45, CC2D1A, ZNF48, RELA, TIGD5, ZNF384, MZF1, ZNF71, TBP, ZNF668, ZNF335, USF2, PHF20, GLI4, KLF16, POGK, WIZ, ZNF609, ZNF703, ZNF579, ZNF324B, ZBED1, SREBF1, ZNF517, SNAPC2, ZNF687, ZNF646, ZNF740, ZNF263, SREBF2, FOXK2, CAMTA2, BAZ2A, GLYR1, ZNF79, SP1, SGSM2, MBD3, RXRB, SKOR2, SIX5, ZBTB42, ZNF777, TCF3, ESRRA, ZBTB40, NFE2L1, SNAPC4, MAFG, SRF, ZNF512B, ZNF282, ZBTB43, MAZ, ZBTB22, GTF2I, CIC, ZNF143, REXO4, KLF10, ZNF653, ZNF696, FOXK1, ZFPM1, ZNF775, HMG20B, JRK, ZNF213, E2F4, MAFK, SP2, SRCAP, MXD4, NRF1, MBD1, PATZ1, CENPB, PCGF2, ZNF219, FOXJ2, ZNF672, NFYA, JUND, ZNF358, FOXO6, RFX1, ZNF76, ZNF513, MYC, RBCK1, TFAP4, MNT, ZNF444, SLC2A4RG, XBP1, ZNF398, ZNF414, ZNF580, ZBTB17, NR2F6, GTF2B, ZNF575, MECP2, SAFB, ZNF205, ZNF629, ZNF771, ZSCAN22, NR1H2, ZNF688, ZBTB12, THAP11, FLYWCH1, ZNF395, CXXC1, ZNF628, TCF20, ZNF692, YY1, ZNF408, GLMP, MBD6, ARHGAP35, IRF3, ERF, GATAD2A, PRDM4, GATAD2B, CTCF, ZNF7, ATF4, PBX2, AKAP8L, ZC3H8, ZBTB48, ZNF34, ZXDC, ZNF576, ZNF526, REPIN1, ZBTB39, DOT1L, ZGPAT, SKI, ZNF69, ZNF747, THAP4, ZNF496, ZNF880, ZNF787, CENPT, TFE3, HIC2, SPEN, ZNF598, ZNF497, ZNF764, CREB3L4, ZNF574, KDM2A, THAP8, SOX12, SON, ZNF584, ZNF664, ANKZF1, ZNF22, ZNF837, ZNF18, ZNF346, ZNF212, ZNF691, THAP3, AHCTF1, ZNF276, ZNF3, TCFL5, GZF1, MLX, FOXP4, XPA, ZBTB9, ZNF57, PLAGL2, DDIT3, ZNF525, UBP1, ZNF830, ZNF707, ZNF410, ZNF202, FOXO4, CREB3, ADNP2, ZFP91, ISL2, PREB, CENPX, ZSCAN16, AKAP8, ZNF524, ZNF16, ATMIN, ZBED4, ATF6B, THAP7, ZNF296, MXD3, DNTTIP1, CHAMP1, ZNF511, NAIF1, DRAP1, ZNF581"
cluster_2_up = set(cluster_2_up.split(", "))

425, TIGD6, SP3, HMX3, ZNF526, ZC3H8, BAZ2B, CREBZF, ZNF709, ZNF77, ZNF211, ZNF7, ZNF519, ZNF37A, PRDM13, ZNF470, NFX1, AEBP2, ZBTB21, ZNF577, GTF2IRD2B, ZNF264, ZNF257, ZNF254, ZNF788P, ZNF70, ZNF200, SMAD4, IKZF5, ZNF501, ZFY, ZNF684, ZNF433, ZNF235, ZNF624, ZNF891, ZNF556, ZNF627, ZNF407, ZNF83, ZNF551, ZNF484, ZNF134, SETDB2, ZNF568, ZNF283, ZNF175, ZNF525, ZNF599, ATMIN, THAP4, ZNF441, ZNF426, ZNF558, RLF, ZFP91, ZBTB44, KAT7, ZNF320, ZNF148, PURA, ZSCAN5C, ZNF724, ZNF502, ZNF548, MYSM1, ZSCAN12, KCMF1, ZNF583, BBX, ZNF790, ZNF449, ZNF665, ZNF79, ZNF500, ZNF785, ZNF160, ZSCAN22, ZSCAN20, ZBTB41, ZBED6, ZNF354B, ZNF836, GMEB1, ZNF518B, ZSCAN9, FOXJ3, ZNF550, THAP8, ZNF430, PKNOX1, PREB, ZNF81, ZNF816, ZNF486, ZNF468, ZNF419, CENPX, ZNF250, ZNF439, ZNF460, ZNF713, ZNF585B, SMAD5, ZNF41, ZNF582, ZNF615, ZNF189, ZNF606, ZNF251, THAP6, ZNF280D, ZSCAN26, ZNF585A, ZNF10, ZFAT, ZKSCAN8, ZNF529, ZNF805, ZNF747, ZNF329, ZNF432, ZNF491, ZNF732, ZNF875, ZNF764, ZNF343, MGA, ZNF611, PRDM10, MIXL1, BHLHE23, PROX2, ZNF735, ZNF879, ZNF786, BPTF, ZNF225, ZFP82, ZNF605, ZNF417, SON, ZNF554, ZNF578, ZBTB3, ZNF808, ZNF555, ZNF461, ZNF566, ZNF736, REXO4, AHRR, ZNF610, ZNF136, ZFP14, ZNF132, ZSCAN25, ZNF431, ZNF776, ZNF317, HINFP, ZNF20, ZNF398, LEUTX, ZNF594, ZKSCAN7, ZKSCAN3, ZNF226, ZNF573, GTF2IRD2, ZNF493, ZNF621, NFAT5, ZNF268, ZNF774, ZSCAN30, PRDM15, CARF, ZNF304, ZFP30, ZNF559, ZNF345, ZNF347, ZNF253, ZNF780B, ZNF626, ZNF510, ZNF623, ZNF141, ZBTB38, ZMAT1, ZBED5, ZNF549, ZNF630, ASH1L, KMT2A, ZNF133, ZNF793, NR2C1, ZNF705E, ZNF814, ZNF337, ZNF778, ZNF699, ZNF791, ZNF562, ZNF708, ZNF16, ZNF737, ZNF382, ZNF471, ZNF844, ZNF8, ZNF596, ZNF445, ZNF236, ZNF408, RFX7, ZNF333, ZNF157, ZNF677, ZNF397"
cluster_1_dn = set(cluster_1_dn.split(", "))

# %%
for cluster in [cluster_1_up, cluster_2_up, cluster_1_dn]:
    print(cluster.intersection(union_set))
# Out:
# {'HBP1', 'ZNF438', 'IRF4', 'GCM1', 'ETV3L', 'EGR2', 'ZNF394', 'ZBTB3'}
# {'ATMIN', 'ZBTB43', 'ZNF592', 'GATAD2B', 'ARHGAP35', 'ZBTB17', 'TCFL5'}
# {'ZNF789', 'ATMIN', 'PA2G4', 'ZNF644', 'ZNF407', 'ZNF772', 'KCMF1', 'ZNF566', 'THAP9', 'MYSM1', 'KIN', 'ZNF419', 'ZKSCAN5', 'ZNF816', 'ZBTB3', 'ZNF326'}

# %%
from venny4py.venny4py import *

# %%
#dict of sets
sets = {
    'SOX10 ReMap Chip-seq': union_set,
    'Melanoma ChEA Up Genes -1 (C3 SOX10 High)': cluster_1_up,
    'Melanoma ChEA Up Genes -2 (C3 SOX10 High)': cluster_2_up,
    'Melanoma ChEA Dn Genes (C3 SOX10 High)': cluster_1_dn,
}
    
venny4py(sets=sets)

# %%
from helpers import augment_proteomics
import pandas as pd

# %%
augmented_clusters = {}
for i, cluster in enumerate([cluster_1_up, cluster_2_up, cluster_1_dn]):
    prot_prot_coexp = pd.read_csv('process_cptac/out/ccleproteomics_normalized_gene_correlation_matrix.txt.gz', sep='\t', compression='gzip', index_col=0)
    augmented_clusters[i] = augment_proteomics(cluster, prot_prot_coexp)

# %%
def submit_to_enrichr(geneset, description): 
    import requests
    import json
    ENRICHR_URL = 'https://maayanlab.cloud/Enrichr/addList'
    genes_str = '\n'.join(geneset)
    description = description
    payload = {
        'list': (None, genes_str),
        'description': (None, description)
    }
    response = requests.post(ENRICHR_URL, files=payload)
    if not response.ok:
        raise Exception('Error analyzing gene list')
    data = json.loads(response.text)
    print(f'https://maayanlab.cloud/Enrichr/enrich?dataset={data["shortId"]}')
    return data

# %%
labels = {
    4: 'SOX10 ReMap Chip-seq',
    0: 'Melanoma ChEA Up Genes -1 (C3 SOX10 High)',
    1: 'Melanoma ChEA Up Genes -2 (C3 SOX10 High)',
    2: 'Melanoma ChEA Dn Genes (C3 SOX10 High)',
}

# %%
for k in augmented_clusters:
    print(labels[k] + " with protein-protein coexpression")
    submit_to_enrichr(augmented_clusters[k] + list(sets[labels[k]]), labels[k] + " with protein-protein coexpression")
    print(labels[k])
    submit_to_enrichr(augmented_clusters[k] + list(sets[labels[k]]), labels[k])
# Out:
# Melanoma ChEA Up Genes -1 (C3 SOX10 High) with protein-protein coexpression
# https://maayanlab.cloud/Enrichr/enrich?dataset=0bc9244fd93fe4114d5f91b18d618458
# Melanoma ChEA Up Genes -1 (C3 SOX10 High)
# https://maayanlab.cloud/Enrichr/enrich?dataset=875c93710eea26ff28f33cb3db4328eb
# Melanoma ChEA Up Genes -2 (C3 SOX10 High) with protein-protein coexpression
# https://maayanlab.cloud/Enrichr/enrich?dataset=ccc8c452d10d4c90fa38fa3f58efcb96
# Melanoma ChEA Up Genes -2 (C3 SOX10 High)
# https://maayanlab.cloud/Enrichr/enrich?dataset=90615e74832affe11f5f7a366bb4ce0b
# Melanoma ChEA Dn Genes (C3 SOX10 High) with protein-protein coexpression
# https://maayanlab.cloud/Enrichr/enrich?dataset=42ed55f9d294f0708a4416173cfca14f
# Melanoma ChEA Dn Genes (C3 SOX10 High)
# https://maayanlab.cloud/Enrichr/enrich?dataset=feb9cc4ebb3e96640d9ed3470d4cfdc7
